# %% [markdown]
# This paper looked at a study where bone marrow was taken from 4 healthy patients (BM1-BM4), 3 patients with thalassemia major (BT1-BT3) and 5 patients with sickle cell disorder (SCD1-SC5). From this bone marrow, the CD34+ cells were analyzed using 10X chromium platform.

# %% [markdown]
# Also, this random snippet of a quote: "a Lineage depleted CD34+ cells from one normal sample."

# %%
# Source: https://gemini.google.com/app/6786779c01ca26d5
 
import pandas as pd
import numpy as np

# Assuming your data is in a tab-separated format (common for gene expression matrices)
# data = pd.read_csv("./GSE133181_series_matrix.txt", sep="\t", header=0, index_col=0)
# data = pd.read_csv("./GSE133181_series_matrix_pt1.txt", sep="\t", header=0, index_col=0)
data = pd.read_csv("./GSE133181_series_matrix_pt2.txt", sep="\t", header=0, index_col=0)

# If your data is in a different format (e.g., CSV), adjust the separator and other parameters accordingly.

# Check the dimensions of the data
print("The dimensions of the data are")
print(data.shape)

print("\n\n")

# View the first few rows
print("The first few rows are")
display(data.head())

print("\n\n")

# Get basic statistics about the data
print("Basic stats include")
display(data.describe())

print("\n\n")
# Out:
# The dimensions of the data are
# (44, 13)
#
#
#
# The first few rows are
#                                             BM1                    BM2  \
# !Sample_title
# !Sample_geo_accession                GSM3901485             GSM3901486
# !Sample_status            Public on Oct 01 2019  Public on Oct 01 2019
# !Sample_submission_date             Jun 22 2019            Jun 22 2019
# !Sample_last_update_date            Oct 02 2019            Oct 02 2019
# !Sample_type                                SRA                    SRA
#
#                                             BM3                    BM4  \
# !Sample_title
# !Sample_geo_accession                GSM3901487             GSM3901488
# !Sample_status            Public on Oct 01 2019  Public on Oct 01 2019
# !Sample_submission_date             Jun 22 2019            Jun 22 2019
# !Sample_last_update_date            Oct 02 2019            Oct 02 2019
# !Sample_type                                SRA                    SRA
#
# ...

# %%
# printing my csv

# Source: https://gemini.google.com/app/6786779c01ca26d5
 
import pandas as pd 
data = pd.read_csv("./GSE133181_series_matrix_pt2.txt", sep="\t", header=0, index_col=0)

# print(data)
display(data)
# Out:
#                                                                                BM1  \
# !Sample_title
# !Sample_geo_accession                                                   GSM3901485
# !Sample_status                                               Public on Oct 01 2019
# !Sample_submission_date                                                Jun 22 2019
# !Sample_last_update_date                                               Oct 02 2019
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                           normal donor's bone marrow cells
# !Sample_organism_ch1                                                  Homo sapiens
# !Sample_characteristics_ch1                               individual: normal donor
# !Sample_characteristics_ch1                                    tissue: bone marrow
# ...

# %%
print("hello world")
# Out:
# hello world
